# %%
import verification as vf
dataFrameChanged, dataFrame = vf.verifyPark("NAVA", color=True)

# %%
dataFrameChanged
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9476">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9476_level0_col0" class="col_heading level0 col0" >UnitCode</th>
#       <th id="T_c9476_level0_col1" class="col_heading level0 col1" >Field</th>
#       <th id="T_c9476_level0_col2" class="col_heading level0 col2" >Label</th>
#       <th id="T_c9476_level0_col3" class="col_heading level0 col3" >Code</th>
#       <th id="T_c9476_level0_col4" class="col_heading level0 col4" >INSTATS</th>
#       <th id="T_c9476_level0_col5" class="col_heading level0 col5" >REC</th>
#       <th id="T_c9476_level0_col6" class="col_heading level0 col6" >RECH</th>
#       <th id="T_c9476_level0_col7" class="col_heading level0 col7" >NREC</th>
#       <th id="T_c9476_level0_col8" class="col_heading level0 col8" >NRECH</th>
#       <th id="T_c9476_level0_col9" class="col_heading level0 col9" >CL</th>
# ...

# %%
dataFrame
# Out:
#    UnitCode    Field                                      Label    Code  \
# 0      NAVA    Input  BEGINNING TRAFFIC COUNT AT VISITOR CENTER      F1
# 1      NAVA    Input                  A/V HISATSIMON ATTENDANCE     F10
# 2      NAVA    Input                   A/V BETATAKIN ATTENDANCE     F12
# 3      NAVA    Input                  A/V LASER SHOW ATTENDANCE    F12B
# 4      NAVA    Input            NAVAJO BASKETRY FILM ATTENDANCE    F12C
# ..      ...      ...                                        ...     ...
# 68     NAVA  Formula                  Rec Visitor Hours Arizona  TRVHAZ
# 69     NAVA  Formula                                       TRVS    TRVS
# 70     NAVA  Formula               NPS CG RV Overnights Arizona  TRVSAZ
# 71     NAVA  Formula                                         TT      TT
# 72     NAVA  Formula             NPS CG Tent Overnights Arizona    TTAZ
#
#     INSTATS    REC   RECH   NREC  NRECH     CL    CCG     BC     TT   TRVS  \
# ...
