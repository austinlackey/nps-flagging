# %%
import verification as vf
dataFrameChanged, dataFrame = vf.verifyPark("MORA", color=True)

# %%
dataFrameChanged
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8819">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8819_level0_col0" class="col_heading level0 col0" >UnitCode</th>
#       <th id="T_f8819_level0_col1" class="col_heading level0 col1" >Field</th>
#       <th id="T_f8819_level0_col2" class="col_heading level0 col2" >Label</th>
#       <th id="T_f8819_level0_col3" class="col_heading level0 col3" >Code</th>
#       <th id="T_f8819_level0_col4" class="col_heading level0 col4" >INSTATS</th>
#       <th id="T_f8819_level0_col5" class="col_heading level0 col5" >REC</th>
#       <th id="T_f8819_level0_col6" class="col_heading level0 col6" >RECH</th>
#       <th id="T_f8819_level0_col7" class="col_heading level0 col7" >NREC</th>
#       <th id="T_f8819_level0_col8" class="col_heading level0 col8" >NRECH</th>
#       <th id="T_f8819_level0_col9" class="col_heading level0 col9" >CL</th>
# ...

# %%
dataFrame
# Out:
#     UnitCode    Field                                           Label    Code  \
# 0       MORA    Input             TRAFFIC COUNT AT NISQUALLY ENTRANCE      F1
# 1       MORA    Input         TRAFFIC COUNT AT CAYUSE PASS (410 WEST)     F10
# 2       MORA    Input                WINTER ESTIMATES FOR WHITE RIVER    F10A
# 3       MORA    Input                            BUSES AT WHITE RIVER     F11
# 4       MORA    Input          TRAFFIC  COUNT AT WHITE RIVER ENTRANCE    F11A
# ..       ...      ...                                             ...     ...
# 107     MORA  Formula               NPS Campground RV Overnight Stays    TRVS
# 108     MORA  Formula    NPS Campground RV Overnight Stays Washington  TRVSWA
# 109     MORA  Formula                    Recreation Visits Washington   TRVWA
# 110     MORA  Formula             NPS Campground Tent Overnight Stays      TT
# 111     MORA  Formula  NPS Campground Tent Overnight Stays Washington    TTWA
#
# ...
